# %%
import pandas as pd
import ptitprince as pt
import seaborn as sns
import os
import matplotlib.pyplot as plt
import numpy as np
import os
from datetime import datetime

#sns.set(style="darkgrid")
#sns.set(style="whitegrid")
#sns.set_style("white")
sns.set(style="whitegrid",font_scale=2)
import matplotlib.collections as clt

# %%
#read csv file with data
df = pd.read_csv ("/home/claire/Documents/STUDY/EEG-Tobacco/DATA/Surveys/Skyline - Daily messages - Intervention_21 May 2019_11.26.csv", sep= ",")

# %%
df1 = df[['StartDate', 'Finished', 'Q1', 'SC0']]

# %%
df1.sort_values(by='Q1')
# Out:
#                                              StartDate  \
# 242                                2019-05-21 11:07:08
# 129                                2019-05-10 10:55:43
# 67                                 2019-05-03 12:33:37
# 132                                2019-05-10 12:54:32
# 65                                 2019-05-03 09:35:46
# 134                                2019-05-10 17:12:13
# 62                                 2019-05-02 16:32:29
# 138                                2019-05-11 10:08:34
# 142                                2019-05-11 13:04:23
# 145                                2019-05-11 16:33:19
# 148                                2019-05-12 09:35:36
# 155                                2019-05-12 15:13:24
# 158                                2019-05-12 17:49:22
# 161                                2019-05-13 10:29:28
# 169                                2019-05-13 16:34:39
# 174                                2019-05-14 10:08:19
# ...

# %%
# select data for only 1 participant
df_s= df1[df1['Q1']=='558']

# %%
ax = df_s.plot.hist(by=df_s['StartDate'])
# Out:
# 2      2019-04-18 16:46:55
# 3      2019-04-19 09:33:54
# 4      2019-04-19 12:31:32
# 5      2019-04-19 17:46:16
# 6      2019-04-20 09:39:15
# 7      2019-04-20 12:31:32
# 8      2019-04-20 16:44:09
# 9      2019-04-21 10:11:34
# 10     2019-04-21 12:56:41
# 11     2019-04-21 16:50:49
# 12     2019-04-21 12:56:32
# 13     2019-04-22 09:31:37
# 14     2019-04-22 12:32:12
# 15     2019-04-22 16:33:09
# 16     2019-04-23 09:31:41
# 17     2019-04-23 13:26:09
# 18     2019-04-23 16:32:06
# 19     2019-04-24 09:31:34
# 20     2019-04-24 13:24:34
# 21     2019-04-24 16:31:46
# 22     2019-04-25 10:53:59
# 23     2019-04-25 12:34:17
# 24     2019-04-25 16:52:28
# 25     2019-04-26 10:28:20
# 27     2019-04-26 14:03:56
# 29     2019-04-26 16:51:28
# 32     2019-04-27 12:37:43
# 33     2019-04-27 11:02:20
# 35     2019-04-27 16:35:36
# 37     2019-04-28 11:50:27
#               ...
# 64     2019-05-02 16:34:23
# 66     2019-05-03 09:36:25
# 69     2019-05-03 13:20:05
# ...

# %%
# for each day, plot number of response == True
# Out:
#                StartDate Finished   Q1  SC0
# 2    2019-04-18 16:46:55     True  558    3
# 3    2019-04-19 09:33:54     True  558    3
# 4    2019-04-19 12:31:32     True  558    3
# 5    2019-04-19 17:46:16     True  558    3
# 6    2019-04-20 09:39:15     True  558    3
# 7    2019-04-20 12:31:32     True  558    3
# 8    2019-04-20 16:44:09     True  558    3
# 9    2019-04-21 10:11:34     True  558    3
# 10   2019-04-21 12:56:41     True  558    3
# 11   2019-04-21 16:50:49     True  558    2
# 12   2019-04-21 12:56:32    False  558  NaN
# 13   2019-04-22 09:31:37     True  558    3
# 14   2019-04-22 12:32:12     True  558    3
# 15   2019-04-22 16:33:09     True  558    3
# 16   2019-04-23 09:31:41     True  558    3
# 17   2019-04-23 13:26:09     True  558    3
# 18   2019-04-23 16:32:06     True  558    3
# 19   2019-04-24 09:31:34     True  558    3
# 20   2019-04-24 13:24:34     True  558    3
# 21   2019-04-24 16:31:46     True  558    3
# ...
